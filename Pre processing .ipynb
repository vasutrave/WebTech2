# %%
import json
import csv
from pprint import pprint
count = 0
with open('data.json') as f:
    data = json.load(f)

with open('rest_data.csv','w') as writeFile:
    writer = csv.writer(writeFile)

for i in data['restaurants']:
        l =[i['restaurant']['name'],i['restaurant']['location']['locality'],i['restaurant']['location']['address'],i['restaurant']['cuisines'],i['restaurant']['average_cost_for_two'],i['restaurant']['price_range'],i['restaurant']['user_rating']['aggregate_rating'],i['restaurant']['featured_image']]
        print(l)
# Out:
# ['Byg Brewski Brewing Company', 'Sarjapur Road', 'Behind MK Retail, Sarjapur Road, Bangalore', 'Finger Food, North Indian, Italian, Continental, South Indian', 1600, 3, '4.9', 'http://b.zmtcdn.com/data/res_imagery/58882_RESTAURANT_198854337681c7550e349a9e79cf33af.jpg']
# ['Brew and Barbeque - A Microbrewery Pub', 'Soul Space Arena Mall, Marathahalli', '36/4, Fourth Floor, Soul Space Arena, Outer Ring Road, Doddanekkundi Village, Marathahalli, Bangalore', 'Continental, North Indian, BBQ, Steak', 1400, 3, '4.9', 'https://b.zmtcdn.com/data/pictures/chains/7/18254597/b1c3bf22fafcc2fea567659e9ec2d7dd.jpg']
# ['House Of Commons', 'Koramangala 5th Block', '122/B, Jyothi Nivas Road, 5th Block, Koramangala 5th Block, Bangalore', 'Continental, Asian, North Indian', 1000, 3, '4.9', 'https://b.zmtcdn.com/data/pictures/0/18323630/283c2a072c79e4b27c9d13ecf8591505.jpg?output-format=webp']
# ...
